# %%
import pandas as pd
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
from future.utils import iteritems
from collections import Counter
from sklearn.manifold import TSNE
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import pymysql
from gensim.models import word2vec
from tqdm.notebook import tqdm

# %%
article_data = pd.read_csv('mixver9.txt', encoding='utf-8', header= None)
documents = [' '.join(i[0].split(' ')[1:]) for i in article_data.values]

# %%
#print(documents[0])

# %%
as_one = ''
for document in documents:
    as_one = as_one + ' ' + document
words = as_one.split()

# %%
words[0:10]
# Out:
# ['캔', '용기', '친환경', '제품', '활용', '쌀국수', '쌀', '생각', '영어', '강아지']

# %%
counts = Counter(words)

# %%
vocab = sorted(counts, key=counts.get, reverse=True)

# %%
word2idx = {word.encode("utf8").decode("utf8"): ii for ii, word in enumerate(vocab,1)}

# %%
idx2word = {ii: word for ii, word in enumerate(vocab)}

# %%
V = len(word2idx)
N = len(documents)

# %%
tf = CountVectorizer()

# %%
tf.fit_transform(documents)
# Out:
# <1x8549 sparse matrix of type '<class 'numpy.int64'>'
# 	with 8549 stored elements in Compressed Sparse Row format>

# %%
tf.fit_transform(documents)[0:1].toarray()
# Out:
# array([[ 30, 315,  10, ...,   5,  10,  15]], dtype=int64)

# %%
tfidf = TfidfVectorizer(max_features = 1000, max_df=1, min_df=0)

#generate tf-idf term-document matrix
A_tfidf_sp = tfidf.fit_transform(documents)  #size D x V

# %%
tfidf_dict = tfidf.get_feature_names()
print(tfidf_dict)
# Out:
# ['가격', '가구', '가득', '가루', '가방', '가슴', '가요', '가위', '가을', '가이드', '가이드북', '가장', '가족', '가죽', '가지', '가치', '각인', '간식', '간편', '간호', '갈비', '감각', '감귤', '감동', '감성', '감정', '강사', '강아지', '개념', '개발', '개선', '거리', '거울', '거치', '거품', '걱정', '건강', '건조', '건축', '걸이', '검증', '게임', '겨울', '겨울나기', '결혼', '경량', '경력', '경험', '계란', '계절', '고급', '고기', '고래', '고민', '고양이', '골드', '공간', '공감', '공개', '공기', '공룡', '공부', '공식', '공연', '공용', '공존', '관리', '광고', '괴물', '교육', '교체', '구독', '구두', '구름', '구리', '구성', '구스', '국내', '국민', '국산', '귀걸이', '규어', '그녀', '그대', '그린', '그림', '그림책', '기념', '기능', '기록', '기름', '기모', '기본', '기부', '기분', '기술', '기억', '기적', '기준', '기타', '기획', '김치', '깔창', '꿀잠', '나노', '나무', '나이트', '남녀', '남성', '남자', '낭만', '내내', '냄새', '네이버웹툰', '노래', '노트', '노트북', '노하우', '놀이', '높이', '누리', '느낌', '니트', '다른', '다리', '다운', '다이아', '다이아몬드', '다이어리', '다이어트', '다크', '닥터', '단독', '단백질', '단편', '단편영화', '단행본', '달달', '달력', '달빛', '달콤', '담요', '대로', '대신', '대표', '대학', '대학교', '대학생', '대한', '대한민국', '대형', '대화', '덕후', '데님', '데스크', '데이', '도구', '도마', '도시', '도예', '도자기', '도전', '독도', '독립', '독일', '동네', '동물', '동시', '동양', '동화', '두번째', '두유', '두피', '드라마', '드로잉', '드로즈', '등장', '디자이너', '디자인', '디저트', '디지털', '떡볶이', '라면', '라이트', '라이프', '러닝', '러브', '럭셔리', '런칭', '레깅스', '레더', '레드', '레시피', '레이', '레이스', '레이어', '레트로', '로맨스', '로우', '로컬', '로퍼', '리다', '리드', '리버시', '리스', '리얼', '리텍', '마법', '마사지', '마스크', '마약', '마우스', '마을', '마음', '마이', '마케팅', '만난', '만남', '만능', '만들기', '만족', '만족도', '만화', '만화책', '맛집', '맞춤', '매듭', '매력', '매출', '매트', '매트리스', '머그컵', '머리', '머신', '머플러', '먼지', '멀티', '메리', '메리노', '메모', '메이드', '메이커', '메이크업', '면역', '멸종위기', '명작', '명품', '모공', '모니터', '모던', '모든', '모바일', '모습', '모양', '모음', '모이', '모자', '모집', '모찌', '목걸이', '목도리', '무게', '무대', '무드', '무드등', '무릎', '무선', '무스', '무엇', '문구', '문제', '문학', '문화', '물결', '뮤지컬', '미국', '미니', '미니백', '미백', '미생물', '미술', '미스트', '민화', '밀크', '바다', '바디', '바람', '바이오', '바지', '박스', '반려', '반려견', '반려동물', '반지', '반짝', '받침', '발견', '발라', '발매', '발열', '발효', '밤하늘', '방법', '방석', '방수', '방식', '방지', '방향', '배경', '배송', '백팩', '백화점', '밴드', '밸런스', '뱃지', '뱅쇼', '버려진', '버블', '버전', '버킷', '버터', '버핏', '벌꿀', '베개', '베다', '베리', '베스트', '베이스', '베타', '벨벳', '벨트', '변신', '변화', '별자리', '보고', '보관', '보드', '보드게임', '보따리', '보석', '보습', '보온', '보이', '보증', '보호', '복숭아', '본격', '부담', '부부', '부산', '부자', '부츠', '분리', '분석', '분위기', '브라', '브라운', '브랜드', '브러쉬', '브루', '브릭', '블랙', '블럭', '블록', '블루', '비건', '비누', '비밀', '비법', '비타민', '비트', '빈티', '뿌리', '사계절', '사과', '사람', '사랑', '사용', '사이', '사이즈', '사이클링', '사전', '사진', '삭스', '산책', '살균', '상상', '상점', '새해', '색감', '샌드', '생각', '생명', '생산', '생존', '생활', '샤워', '샤인', '샴푸', '서비스', '서울', '서포터', '선물', '선인장', '설치', '설탕', '섬유', '성공', '성분', '성장', '세계', '세상', '세척', '세탁', '세트', '센스', '셀프', '셋업', '셔츠', '셰프', '소개', '소금', '소녀', '소리', '소설', '소스', '소원', '소장', '소재', '소파', '소품', '소프트', '손목', '솔루션', '수건', '수납', '수면', '수분', '수제', '수채화', '수트', '숙면', '순간', '순이', '숨기', '스니커즈', '스마트', '스마트폰', '스카프', '스케치업', '스크래쳐', '스키', '스타', '스타일', '스탠드', '스텀', '스테이크', '스토리', '스톤', '스튜디오', '스트랩', '스트레스', '스티커', '스틱', '스파', '스페셜', '스펙', '스포츠', '스푼', '스피커', '슬랙스', '슬림', '슬링', '습관', '시간', '시계', '시대', '시리즈', '시인', '시작', '시즌', '시집', '시트', '식단', '식물', '식초', '식탁', '신고', '신발', '신소재', '신화', '실내', '실리콘', '실무', '실버', '실용', '실전', '실천', '실크', '실화', '심리', '심플', '싱글', '쓰레기', '아기', '아동', '아빠', '아웃도어', '아이', '아이템', '아이패드', '아침', '아크릴', '아트', '아티스트', '아파트', '안감', '안경', '안내서', '안대', '안심', '안전', '알파카', '앞치마', '애니메이션', '애플', '액세서리', '액션', '액자', '앨범', '앰플', '양말', '양면', '양식', '어깨', '어른', '어린이', '어서', '언택트', '얼굴', '엄마', '업무', '에너지', '에디', '에세이', '에센스', '에어', '에어팟', '에코', '에코백', '엑스트라', '여름', '여성', '여유', '여자', '여정', '여행', '여행지', '역사', '연구', '연극', '연기', '연말', '연어', '연주', '연출', '엽서', '영국', '영상', '영양', '영어', '영화', '영화제', '예방', '예술', '예술가', '오디오', '오르다', '오리', '오버', '오브', '오일', '오픈', '온기', '온라인', '올인원', '올해', '옷장', '와디', '완성', '왕실', '외출', '요가', '요리', '용기', '용량', '용품', '우드', '우산', '우울', '우주', '운동', '운영', '움직', '워치', '워커', '워터', '원단', '원료', '원목', '원피스', '월간', '웨어', '웨이', '웹툰', '위드', '위로', '위생', '위해', '유기견', '유기농', '유기동물', '유니크', '유럽', '유리', '유모차', '유산균', '유지', '음반', '음식', '음식물', '음악', '응원', '의류', '이기', '이니셜', ' ...

# %%
import sys
if sys.version_info <= (2,7):
    reload(sys)
    sys.setdefaultencoding('utf-8')
import konlpy
from konlpy.tag import Kkma, Okt, Hannanum

kkma = Kkma()
okt = Okt()
hannanum = Hannanum()
print('konlpy version = %s' % konlpy.__version__)
# Out:
# konlpy version = 0.5.2

# %% [markdown]
# ## 하늘마당

# %%
sent='''
당장 밥말아 먹고 싶은 파스타가 왔다! 데이루나 바지락 국물 파스타
강화도 청소년들이 전하는 섬의 이야기가 담긴 고구마를 요리로 즐겨보세요!
고급향수야? 룸스프레이야? 전세계 고급호텔 향 3만원대 한병에 담다!
7일 한정크리스마스 할머니의 산나물을 담은 오감만족 크리스마스 만찬
집콕필수템 NO설탕 NO물엿 상큼감귤 프리바이오틱 비타민 젤리
모공 연구 10년 흡수 노하우 스위스 검증 비타민C 화장품
7일 단골특집 펀딩요청쇄도! 모공쫙~맑고 탱탱한 피부변화오메가믹스
완판신화 돌아왔다! 김은 먹고 다니냐? 명품 해남 곱창김 100
단 한 권에 열 권을 담은 당신을 위한 디지털 다이어리 SOK
뻔한 음식 말고 간편한 장어로! 세상 맛있는 꿀장어 홈키트
누적 구매평 7천건 찐리뷰가 인정하는 찐 춘천 닭갈비를 간편하게!
200개 한정 제주 매거진 인iiin과 제주 로컬푸드 정기배송!
와인전문가가 추천하는 셰프소믈리에 캐링백+와인잔 컬렉션
입 냄새나 숨 쉬지마! 이제 모과글로 숨 크게 쉬자!
업그레이드 앵콜 다시한번 가격파괴 차량용 무선충전 거치대 핸디그랩
즐거운 요리의 시작 상하좌우 내부까지 ALL 티타늄 도마
45년 전통 3대째 내려오는 비법 된장콩잎
글로벌 26억펀딩 1만원대 6in1만능케이블 inCharge6'''
#print('꼬꼬마 명사: ', kkma.nouns(sent))
print(okt.nouns(sent))
#print('한나눔 명사: ', hannanum.nouns(sent))
# Out:
# ['당장', '밥말', '파스타', '데이', '루나', '바지락', '국물', '파스타', '강화도', '청소년', '전하', '섬', '이야기', '고구마', '요리', '고급', '향수', '룸', '스프레이', '전세계', '고급', '호텔', '향', '병', '한정', '크리스마스', '할머니', '산나물', '오감', '만족', '크리스마스', '만찬', '집콕', '필수', '템', '설탕', '물엿', '상큼', '감귤', '프리바이오틱', '비타민', '젤리', '모공', '연구', '흡수', '노하우', '스위스', '검증', '비타민', '화장품', '단골', '특집', '펀딩', '요청', '쇄도', '쫙', '피부', '변화', '메가믹스', '완판', '신화', '김', '명품', '해남', '곱창', '김', '단', '권', '열', '권', '당신', '위', '디지털', '다이어리', '음식', '장어', '세상', '꿀', '장어', '홈', '키트', '누적', '구매', '평', '리뷰', '인정', '춘천', '닭갈비', '개', '한정', '제주', '인', '과', '제주', '로컬', '푸드', '정기', '배송', '와인', '전문가', '추천', '셰프', '소믈리에', '캐링', '와인잔', '컬렉션', '입', '냄새', '숨', '이제', '모과', '글', '숨', '크게', '업그레이드', '앵콜', '다시', '한번', '가격파괴', '차량', '용', '무선', '충전', '거치', '핸', '디그', '랩', '요리', '시작', '상하좌우', '내부', '티타늄', '도마', '전통', '비법', '된장', '콩잎', '글로벌']

# %% [markdown]
# noun_set = set(okt.nouns(sent))
# selected_word = []
#
#
# for i in noun_set:
#     if i in tfidf_dict:
#         selected_word.append(i)
#         continue
# selected_word
# from gensim.models import word2vec
#
# model = word2vec.Word2Vec.load("NaverMovie29.model")
# for i in selected_word:
#     print(i)
#     print(model.wv.most_similar(positive=[i],topn=7))
#     print()
# type(model.wv.most_similar(positive=[i],topn=7))

# %%
conn = pymysql.connect(host='127.0.0.1', port=3306, user='root', password='0000',db='test', charset='utf8')

curs = conn.cursor()


#print('꼬꼬마 명사: ', kkma.nouns(sent))
#print(okt.nouns(sent))
#print('한나눔 명사: ', hannanum.nouns(sent))
username="듀듀"
sql = "select distinct I.title from test.user_info I, test.crawl C where username like '%s' and C.title = I.title;"%username
sql1 = "select distinct I.title, C.category from test.user_info I, test.crawl C where username like '%s' and C.title = I.title;"%username

curs.execute(sql)
sent = curs.fetchall()


curs.execute(sql1)
title_with_category = curs.fetchall()
print("=======title with category=========")
#print(title_with_category)
print("=======title with category=========")

noun_set = set(okt.nouns(str(sent)))
selected_word = []
#print(sent)
sent_list = list(sent)
sent_list2 = []
for i in sent_list:
    sent_list2.append(list(i))
#print(sent_list2)
#selected_word : tokenized word from user's funding title list
for i in noun_set:
    if i in tfidf_dict:
        selected_word.append(i)
        continue
final_word_list = []
category_list=[]
print("=======category list=======")
for i in selected_word:
    sql3 = "select distinct I.title, C.category from test.user_info I, test.crawl C where username like '{username}' and C.title = I.title and I.title like '%%{word}%%';".format(username=username, word=i);
    curs.execute(sql3)
    rows = curs.fetchall()
    #print(rows)
    
    for j in rows:
        if i in j[0]:
            final_word_list.append(i)
            category_list.append(j[1])
            #print(i, j[1])
print("=======category list=======")  

model = word2vec.Word2Vec.load("NaverMovie29.model")
word_len = len(final_word_list)
category_len = len(category_list)
count=0
for i in tqdm(range(word_len)):
    print(final_word_list[i], category_list[i])
    print()
    similar_word=model.wv.most_similar(positive=[final_word_list[i]],topn=7)
    for j in similar_word:
        if len(j[0])==1:
            continue
        else:
            print(j[0])
            sql = "select DISTINCT pagename, category, title from test.crawl where title like '%%%s%%'" %j[0]
            curs.execute(sql)
            words = curs.fetchall()
            conn.commit()
            #print(words)
            length = len(words)
            if length>3:
                length = 3
            #print(length)
            for k in range(0,length):
                tmp=[]
                tmp.append(''.join(list(words[k][2])))
                if words[k][1] == category_list[i] and tmp not in sent_list2 :
                    print(words[k])
                    count=count+1

                    
    print()

print(count)
conn.close()
# Out:
# =======title with category=========
# =======title with category=========
# =======category list=======
# =======category list=======
#   0%|          | 0/6 [00:00<?, ?it/s]
# 규어 예술
#
# 랜덤
# ('tumblbug', '예술', '아리랑은 고양이들 랜덤피규어 Vol.12')
# ('tumblbug', '예술', '몰랑이 할로윈 랜덤 피규어 Vol.2  몰랑 호러쇼')
# 아리
# 호러
# ('tumblbug', '예술', '몰랑이 할로윈 랜덤 피규어 Vol.2  몰랑 호러쇼')
# 스승
# ('tumblbug', '예술', '겨레의 큰스승 백범 김구 선생님 피규어')
# 선생님
# ('tumblbug', '예술', '겨레의 큰스승 백범 김구 선생님 피규어')
# 할로윈
# ('tumblbug', '예술', '몰랑이 할로윈 랜덤 피규어 Vol.2  몰랑 호러쇼')
#
# 힐링 디자인
#
# 아이콘
# ('tumblbug', '디자인', '나는 익명이고 너를 조아해! 힐링아이콘 익명이 퍼퓸태그')
# 익명
# ('tumblbug', '디자인', '익명이 모찌모찌 납작대형 쿠션  5가지 모찌쿠션')
# 만다라
# ('wadiz', '디자인', '보기만 해도 힐링이 돼요. 드로잉 리추얼 만다라 일러스트 디자인문구')
# ('tumblbug', '디자인', '나를 찾는 시간 힐링 만다라 KIT 유유자점')
# 리추얼
# ('wadiz', '디자인', '보기만 해도 힐링이 돼요. 드로잉 리추얼 만다라 일러스트 디자인문구')
# 불멍
# ('wadiz', '디자인', 'AA 팔성화로  불멍으로 당신을 힐링시켜드립니다.')
# 붓기
# 상속
#
# 힐링 예술
#
# 아이콘
# 익명
# 만다라
# 리추얼
# 불멍
# 붓기
# 상속
#
# 다이어리 디자인
#
# 애뽈
# ('tumblbug', '디자인', '애뽈의 2021 숲소녀 다이어리달력')
# ('tumblbug', '디자인', '애뽈의 2020 숲소녀 다이어리달력')
# 캡처
# 파크
# ('tumblbug', '디자인', '모든 소망을 현실로 2020 루나파크 다이어리')
# ('tumblbug', '디자인', '모든 행운을 너에게 2019 루나파크 다이어리')
# 만년
# ('tumblbug', '디자인', '버려진 자투리 가죽에서 찾은 시간의 조각 만년달력 손거울')
# 여섯
# ('tumblbug', '디자인', '오늘도 힘들었을 당신을 위한 샤인플라워 여섯가지 꽃말들')
# ('tumblbug', '디자인', '여섯달의 기록 mon journal 다이어리')
# ('tumblbug', '디자인', '열여섯 딸과 함께 만든 만년 다이어리')
# 러브스토리
# 물고기
# ('tumblbug', '디자인', '2021 계절을 알려주는 물고기 계향어')
#
# 익명 디자인
#
# 아이콘
# ('tumblbug', '디자인', '나는 익명이고 너를 조아해! 힐링아이콘 익명이 퍼퓸태그')
# 사건
# 파크
# ('tumblbug', '디자인', '모든 소망을 현실로 2020 루나파크 다이어리')
# ('tumblbug', '디자인', '모든 행운을 너에게 2019 루나파크 다이어리')
# 소셜
# 규어
# 윌벤져스
# ('tumblbug', '디자인', '윌벤져스 2021 다이어리 키트')
# ('tumblbug', '디자인', '윌벤져스 첫 굿즈! 윌리엄 벤틀리 인형')
# 미디어
#
# 익명 예술
#
# 아이콘
# 사건
# 파크
# 소셜
# 규어
# ('tumblbug', '예술', '아리랑은 고양이들 랜덤피규어 Vol.12')
# ('tumblbug', '예술', '몰랑이 할로윈 랜덤 피규어 Vol.2  몰랑 호러쇼')
# 윌벤져스
# 미디어
#
# 28

# %%
conn = pymysql.connect(host='127.0.0.1', port=3306, user='root', password='0000',db='test', charset='utf8')

curs = conn.cursor()


#print('꼬꼬마 명사: ', kkma.nouns(sent))
#print(okt.nouns(sent))
#print('한나눔 명사: ', hannanum.nouns(sent))
username="해사월"
sql = "select distinct I.title from test.user_info I, test.crawl C where username like '%s' and C.title = I.title;"%username
sql1 = "select distinct I.title, C.category from test.user_info I, test.crawl C where username like '%s' and C.title = I.title;"%username

curs.execute(sql)
sent = curs.fetchall()


curs.execute(sql1)
title_with_category = curs.fetchall()
print("=======title with category=========")
#print(title_with_category)
print("=======title with category=========")

noun_set = set(okt.nouns(str(sent)))
selected_word = []
#print(sent)
sent_list = list(sent)
sent_list2 = []
for i in sent_list:
    sent_list2.append(list(i))
#print(sent_list2)
#selected_word : tokenized word from user's funding title list
for i in noun_set:
    if i in tfidf_dict:
        selected_word.append(i)
        continue
final_word_list = []
category_list=[]
print("=======category list=======")
for i in selected_word:
    sql3 = "select distinct I.title, C.category from test.user_info I, test.crawl C where username like '{username}' and C.title = I.title and I.title like '%%{word}%%';".format(username=username, word=i);
    curs.execute(sql3)
    rows = curs.fetchall()
    #print(rows)
    
    for j in rows:
        if i in j[0]:
            final_word_list.append(i)
            category_list.append(j[1])
            #print(i, j[1])
print("=======category list=======")  

model = word2vec.Word2Vec.load("NaverMovie29.model")
word_len = len(final_word_list)
category_len = len(category_list)

final_projects=[]
for i in tqdm(range(word_len)):
    print(final_word_list[i], category_list[i])
    print()
    similar_word=model.wv.most_similar(positive=[final_word_list[i]],topn=7)
    for j in similar_word:
        if len(j[0])==1:
            continue
        else:
            
            sql = "select DISTINCT pagename, category, title from test.crawl where title like '%%%s%%'" %j[0]
            curs.execute(sql)
            words = curs.fetchall()
            conn.commit()
            #print(words)
            length = len(words)
            if length>3:
                length = 3
            #print(length)
            for k in range(0,length):
                tmp=[]
                tmp.append(''.join(list(words[k][2])))
                if words[k][1] == category_list[i] and tmp not in sent_list2 :
                    print(j[0])
                    final_projects.append(words[k])
                    


final_projects_set = set(final_projects)
for i in final_projects_set:
    print(i)
print(len(final_projects_set))
conn.close()
# Out:
# =======title with category=========
# =======title with category=========
# =======category list=======
# =======category list=======
#   0%|          | 0/39 [00:00<?, ?it/s]
# 정원 만화
#
# 테헤란로
# 테헤란로
# 상가
# 상가
# 수영장
# 궁궐
# 종류
# 종류
# 펜트하우스
# 펜트하우스
# 펜트하우스
# 오컬트
# 배경 만화
#
# 스케치업
# 스케치업
# 스케치업
# 웹툰
# 무협
# 무협
# 무협
# 사극
# 사극
# 사극
# 왕궁
# 왕궁
# 왕궁
# 테헤란로
# 테헤란로
# 해안
# 해안
# 해안
# 배경 만화
#
# 스케치업
# 스케치업
# 스케치업
# 웹툰
# 무협
# 무협
# 무협
# 사극
# 사극
# 사극
# 왕궁
# 왕궁
# 왕궁
# 테헤란로
# 테헤란로
# 해안
# 해안
# 해안
# 배경 만화
#
# 스케치업
# 스케치업
# 스케치업
# 웹툰
# 무협
# 무협
# 무협
# 사극
# 사극
# 사극
# 왕궁
# 왕궁
# 왕궁
# 테헤란로
# 테헤란로
# 해안
# 해안
# 해안
# 토닥 만화
#
# 투닥
# 투닥
# 투닥
# 항구
# 항구
# 중세
# 중세
# 중세
# 해안
# 해안
# 해안
# 왕국
# 공작
# 공작
# 공작
# 대도시
# 대도시
# 토닥 만화
#
# 투닥
# 투닥
# 투닥
# 항구
# 항구
# 중세
# 중세
# 중세
# 해안
# 해안
# 해안
# 왕국
# 공작
# 공작
# 공작
# 대도시
# 대도시
# 엑스트라 만화
#
# 인물
# 클튜
# 클튜
# 뒷골목
# 뒷골목
# 뒷골목
# 해안
# 해안
# 해안
# 외관
# 외관
# 공작
# 공작
# 공작
# 자연 만화
#
# 종이 디자인
#
# 폰트
# 폰트
# 폰트
# 손글씨
# 웹툰 만화
#
# 스케치업
# 스케치업
# 스케치업
# 배경
# 배경
# 배경
# 테헤란로
# 테헤란로
# 왕궁
# 왕궁
# 왕궁
# 해안
# 해안
# 해안
# 중세
# 중세
# 중세
# 세렌
# 세렌
# 세렌
# 웹툰 만화
#
# 스케치업
# 스케치업
# 스케치업
# 배경
# 배경
# 배경
# 테헤란로
# 테헤란로
# 왕궁
# 왕궁
# 왕궁
# 해안
# 해안
# 해안
# 중세
# 중세
# 중세
# 세렌
# 세렌
# 세렌
# 웹툰 만화
#
# 스케치업
# 스케치업
# 스케치업
# 배경
# 배경
# 배경
# 테헤란로
# 테헤란로
# 왕궁
# 왕궁
# 왕궁
# 해안
# 해안
# 해안
# 중세
# 중세
# 중세
# 세렌
# 세렌
# 세렌
# 웹툰 만화
#
# 스케치업
# 스케치업
# 스케치업
# 배경
# 배경
# 배경
# 테헤란로
# 테헤란로
# 왕궁
# 왕궁
# 왕궁
# 해안
# 해안
# 해안
# 중세
# 중세
# 중세
# 세렌
# 세렌
# 세렌
# 웹툰 만화
#
# 스케치업
# 스케치업
# 스케치업
# 배경
# 배경
# 배경
# 테헤란로
# 테헤란로
# 왕궁
# 왕궁
# 왕궁
# 해안
# 해안
# 해안
# 중세
# 중세
# 중세
# 세렌
# 세렌
# 세렌
# 프로젝트 만화
#
# 사막
# 투닥
# 투닥
# 투닥
# 토닥
# 토닥
# 상생
# 프로젝트 만화
#
# 사막
# 투닥
# 투닥
# 투닥
# 토닥
# 토닥
# 상생
# 판타지 만화
#
# 로맨스
# 로맨스
# 저택
# 저택
# 저택
# 중세
# 중세
# 중세
# 대도시
# 대도시
# 토닥
# 토닥
# 왕국
# 투닥
# 투닥
# 투닥
# 판타지 만화
#
# 로맨스
# 로맨스
# 저택
# 저택
# 저택
# 중세
# 중세
# 중세
# 대도시
# 대도시
# 토닥
# 토닥
# 왕국
# 투닥
# 투닥
# 투닥
# 판타지 만화
#
# 로맨스
# 로맨스
# 저택
# 저택
# 저택
# 중세
# 중세
# 중세
# 대도시
# 대도시
# 토닥
# 토닥
# 왕국
# 투닥
# 투닥
# 투닥
# 판타지 만화
#
# 로맨스
# 로맨스
# 저택
# 저택
# 저택
# 중세
# 중세
# 중세
# 대도시
# 대도시
# 토닥
# 토닥
# 왕국
# 투닥
# 투닥
# 투닥
# 판타지 만화
#
# 로맨스
# 로맨스
# 저택
# 저택
# 저택
# 중세
# 중세
# 중세
# 대도시
# 대도시
# 토닥
# 토닥
# 왕국
# 투닥
# 투닥
# 투닥
# 모음 만화
#
# 주거
# 주거
# 주거
# 전망
# 전망
# 원고
# 원고
# 왕궁
# 왕궁
# 왕궁
# 해안
# 해안
# 해안
# 뒷골목
# 뒷골목
# 뒷골목
# 절벽
# 절벽
# 절벽
# 마을 만화
#
# 전망
# 전망
# 해안
# 해안
# 해안
# 왕궁
# 왕궁
# 왕궁
# 외관
# 외관
# 토닥
# 토닥
# 왕국
# 감옥
# 감옥
# 마을 만화
#
# 전망
# 전망
# 해안
# 해안
# 해안
# 왕궁
# 왕궁
# 왕궁
# 외관
# 외관
# 토닥
# 토닥
# 왕국
# 감옥
# 감옥
# 마을 만화
#
# 전망
# 전망
# 해안
# 해안
# 해안
# 왕궁
# 왕궁
# 왕궁
# 외관
# 외관
# 토닥
# 토닥
# 왕국
# 감옥
# 감옥
# 한국 출판
#
# 요괴
# 요괴
# 요괴
# 대백
# 대백
# 대백
# 주택 만화
#
# 상가
# 상가
# 테헤란로
# 테헤란로
# 전망
# 전망
# 수영장
# 왕궁
# 왕궁
# 왕궁
# 해안
# 해안
# 해안
# 초가
# 주택 만화
#
# 상가
# 상가
# 테헤란로
# 테헤란로
# 전망
# 전망
# 수영장
# 왕궁
# 왕궁
# 왕궁
# 해안
# 해안
# 해안
# 초가
# 스케치업 만화
#
# 배경
# 배경
# 배경
# 웹툰
# 왕궁
# 왕궁
# 왕궁
# 중세
# 중세
# 중세
# 해안
# 해안
# 해안
# 주택가
# 주택가
# 주택가
# 스케치업 만화
#
# 배경
# 배경
# 배경
# 웹툰
# 왕궁
# 왕궁
# 왕궁
# 중세
# 중세
# 중세
# 해안
# 해안
# 해안
# 주택가
# 주택가
# 주택가
# 스케치업 만화
#
# 배경
# 배경
# 배경
# 웹툰
# 왕궁
# 왕궁
# 왕궁
# 중세
# 중세
# 중세
# 해안
# 해안
# 해안
# 주택가
# 주택가
# 주택가
# 스케치업 만화
#
# 배경
# 배경
# 배경
# 웹툰
# 왕궁
# 왕궁
# 왕궁
# 중세
# 중세
# 중세
# 해안
# 해안
# 해안
# 주택가
# 주택가
# 주택가
# 스케치업 만화
#
# 배경
# 배경
# 배경
# 웹툰
# 왕궁
# 왕궁
# 왕궁
# 중세
# 중세
# 중세
# 해안
# 해안
# 해안
# 주택가
# 주택가
# 주택가
# 스케치업 만화
#
# 배경
# 배경
# 배경
# 웹툰
# 왕궁
# 왕궁
# 왕궁
# 중세
# 중세
# 중세
# 해안
# 해안
# 해안
# 주택가
# 주택가
# 주택가
# 스케치업 만화
#
# 배경
# 배경
# 배경
# 웹툰
# 왕궁
# 왕궁
# 왕궁
# 중세
# 중세
# 중세
# 해안
# 해안
# 해안
# 주택가
# 주택가
# 주택가
# 폰트 디자인
#
# 어울림
# 어울림
# 시네마
# 앨리스
# 종이
# 종이
# 아티스트
# 아티스트
# 스틱 디자인
#
# 소우
# 시리즈 출판
#
# 앨리스
# 로맨스 만화
#
# 저택
# 저택
# 저택
# 판타지
# 판타지
# 클튜
# 클튜
# 무늬
# 무늬
# 무늬
# 대도시
# 대도시
# 중세
# 중세
# 중세
# 공작
# 공작
# 공작
# ('tumblbug', '만화', '웹툰 스케치업 배경뒷골목UP')
# ('tumblbug', '만화', '웹툰 스케치업 판타지 대도시')
# ('tumblbug', '만화', '게임현대 판타지에 어울리는 SF브러쉬')
# ('tumblbug', '만화', '로판풍 무늬 문양 클튜브러쉬 + 클튜원본 + PNG 세트')
# ('tumblbug', '출판', '은밀하고 위대한 100년의 기록 『타투 디자인 대백과')
# ('tumblbug', '만화', '스케치업 웹툰 배경 19세기 사용인의 공간 9종세트')
# ('tumblbug', '만화', '웹툰판타지 대형도서관 외관+실내6종')
# ('tumblbug', '만화', '스케치업 웹툰 배경  상가주택베이커리 카페')
# ('tumblbug', '출판', '잊혀져 가던 한국의 기묘한 이야기 한국요괴대백과中')
# ('tumblbug', '만화', '로맨스판타지 남주를 위한 로판풍 장식 문양 브러쉬 세트')
# ('tumblbug', '만화', '웹툰 스케치업 해안가 주택 단지')
# ('tumblbug', '출판', '기묘한 이야기 시리즈의 마지막 한국요괴대백과下')
# ('tumblbug', '만화', '스케치업 웹툰배경  로판 공작님의 성')
# ('tumblbug', '만화', '투닥토닥 판타지 스케치업 프로젝트 No.17_ 휴식')
# ('tumblbug', '만화', '투닥토닥 판타지 스케치업 프로젝트 No.10_ 항구도시')
# ('tumblbug', '만화', '스케치업 웹툰배경 무협 사극 동양풍 배경')
# ('tumblbug', '만화', '중세 판타지 왕도대도시')
# ('tumblbug', '만화', '스케치업 웹툰배경 로판 왕궁 배경')
# ('tumblbug', '만화', '웹툰상생프로젝트15 신발 시리즈')
# ('tumblbug', '만화', '웹툰과 일러스트를 위한 꽃브러쉬')
# ('tumblbug', '만화', '스케치업 판타지 마을 배경 성당 시장 해안 절벽')
# ('tumblbug', '만화', '로판용 배경인물엑스트라 슥삭 브러쉬')
# ('tumblbug', '만화', '웹툰 스케치업  테라스 펜트하우스와 자동차')
# ('tumblbug', '만화', '스케치업 웹툰 배경역삼 테헤란로')
# ('tumblbug', '디자인', '나만의 소우주 Mikrokosmos 엽서와 포스터')
# ('tumblbug', '출판', '도깨비와 요괴 신화에 관한 이야기 동양 환상전')
# ('tumblbug', '만화', '스케치업배경 왕궁침실과 물위의정원 set')
# ('tumblbug', '만화', '웹툰스케치업 숲속마녀와 왕궁마법사의 방')
# ('tumblbug', '만화', '세렌 웹툰 스케치업8 호텔 내부세트와 대형서점')
# ('tumblbug', '디자인', '낯섦에서 어울림으로 이주여성의 인식개선과 의료지원')
# ('tumblbug', '만화', '팀파인애플02 아파트단지 역세권주택가')
# ('tumblbug', '만화', '투닥토닥 판타지 스케치업 프로젝트 No.11_로판 성')
# ('tumblbug', '만화', '동양풍 무늬 문양 브러쉬 50종 세트')
# ('tumblbug', '만화', '학원물 필수세트① 액션로맨스 검도태권도장 뒷골목!')
# ('tumblbug', '만화', '웹툰 스케치업 프로젝트_05.주거공간_고양이가 사는 집')
# ('tumblbug', '만화', '동양풍 장식 클튜 소재')
# ('tumblbug', '만화', '웹툰스케치업배경동양환타지무협사극문파')
# ('tumblbug', '만화', '슬기로운 원고생활 동양 무늬 브러쉬')
# ('tumblbug', '만화', '가성비와 효율갑! 클립스튜디오 동굴절벽 응용 브러시~!')
# ('tumblbug', '디자인', 'f o l d r i p. 종이 팝업 드리퍼')
# ('tumblbug', '만화', '스케치업 사장실 10종류.')
# ('tumblbug', '만화', '스케치업 공작실_4 다양한 구성의 로판 대저택 패키지')
# ('tumblbug', '만화', '마법 악마 상징 등 어둡고 신비한 오컬트 소재')
# ('tumblbug', '만화', '관청 감옥 검시실 추국실 조선 배경웹툰 스케치업')
# ('tumblbug', '만화', '음식점상가 5종류')
# ('tumblbug', '만화', '스케치업 웹툰 배경 로판 섬 왕국 패키지')
# ('tumblbug', '디자인', '손글씨 폰트 롱슬림')
# ('tumblbug', '만화', '스케치업 웹툰 배경 펜트하우스')
# ('tumblbug', '출판', '앨리스가 다음 여행자들을 위해 남긴 이상한 가이드북')
# ('tumblbug', '만화', '웹툰 스케치업  뒷골목')
# ('tumblbug', '출판', '신비로운 요괴와 괴물의 이야기 괴물사전  동양편')
# ('tumblbug', '만화', '투닥토닥 판타지 스케치업 프로젝트 No.19_ 사막마을')
# ('tumblbug', '디자인', '상상토끼 아티스트 폰트 시리즈 어울림 in 폰틀리에')
# ('tumblbug', '만화', '세렌 웹툰 스케치업7 테헤란로 도시거리상점가')
# ('tumblbug', '디자인', '상상토끼 시네마틱 폰트 시리즈 강한놈 패밀리')
# ('tumblbug', '만화', '웹툰 배경 스케치업_로판 대저택과 비밀의 화원 세트')
# ('tumblbug', '만화', '스케치업 웹툰배경 팀프리맨의 무협사극 배경4탄')
# ('tumblbug', '만화', '원고 퀄리티를 높일수있는 패턴 모음집')
# ('tumblbug', '만화', '판타지 재판소와 감옥')
# ('tumblbug', '디자인', '상상토끼 아티스트 폰트 시리즈 앨리스 in 폰틀리에')
# ('tumblbug', '만화', '스케치업 전망 좋은 산복도로 마을')
# ('tumblbug', '만화', '네이버웹툰 호러와 로맨스 1~5권완 단행본 제작')
# ('tumblbug', '만화', '［스케치업 웹툰배경］아파트빌라 주거공간 배경')
# ('tumblbug', '만화', '01.궁궐시리즈 창덕궁 첫번째 돈화문과 인정전 까지')
# ('tumblbug', '만화', '앤트 웹툰 스케치업 1  중세 저택내부')
# ('tumblbug', '만화', '웹툰 배경 스케치업_중세 판타지 학교')
# ('tumblbug', '만화', '웹툰사계절 유럽판타지마을 외관+실내3종')
# ('tumblbug', '만화', '스케치업 웹툰배경 자연과 함께 하는 주택가')
# ('tumblbug', '만화', '스케치업 해안마을과 소방차 이삿짐차')
# ('tumblbug', '만화', '스케치업 공작실_3 절벽과 항구가 만난 판타지 마을')
# ('tumblbug', '만화', '스케치업 광역 전망의 마을과 업그레이드 소품 자연물')
# ('tumblbug', '만화', '스케치업 웹툰배경 귀족클럽과 집무실')
# ('tumblbug', '만화', '세렌 웹툰 스케치업 6 신축주택가아파트촌')
# ('tumblbug', '만화', '불개미 판타지 대저택 패키지')
# ('tumblbug', '만화', '로맨스판타지 무늬 문양 프레임 로판풍 브러쉬 세트')
# ('wadiz', '디자인', '색종이화 balance시리즈로 만든 스티커 패브릭 포스터 세트 ')
# ('tumblbug', '만화', '웹툰 배경 프로젝트 01.주거공간 모음 스케치업')
# ('tumblbug', '만화', '스케치업 웹툰  정원과 수영장이 있는 주택 펜트하우스')
# ('tumblbug', '만화', '조선시대 초가 세트3D세트2D전경')
# ('wadiz', '디자인', '레전드 아티스트를 내 방 안으로! 인테리어 포스터 ')
# ('tumblbug', '만화', '웹툰스케치업 배경 서양식 대저택')
# 81

# %% [markdown]
# tmp = '당장 밥말아 먹고 싶은 파스타가 왔다! 데이루나 바지락 국물 파스타'
# tmp2 = []
# tmp2.append(tmp)
# print(tmp2[0])
# sent_list2

# %% [markdown]
# if tmp2 in sent_list2:
#     print("거를 수 있음")
